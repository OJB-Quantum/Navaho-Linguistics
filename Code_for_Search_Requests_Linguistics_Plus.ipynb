# %% [markdown]
# <a href="https://colab.research.google.com/github/OJB-Quantum/Navaho-Linguistics/blob/main/Code_for_Search_Requests_Linguistics_Plus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)

# %%
# !pip install wikipedia-api
# Out:
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from wikipedia-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2023.11.17)
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.6.0

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)

# %%
# !pip install pyshorteners
# Out:
# Collecting pyshorteners
#   Downloading pyshorteners-1.0.1.tar.gz (10.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pyshorteners) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pyshorteners) (2023.11.17)
# Building wheels for collected packages: pyshorteners
#   Building wheel for pyshorteners (setup.py) ... done
#   Created wheel for pyshorteners: filename=pyshorteners-1.0.1-py3-none-any.whl size=17481 sha256=f19dcdd7612a2fd8a934ed74c3eef8381ca7a553bad63d13ffb7e06392e84cf3
#   Stored in directory: /root/.cache/pip/wheels/d5/ff/b3/16d8906f92ab0b042f76a4696fcea11d291d79a2b3a3de1e78
# Successfully built pyshorteners
# Installing collected packages: pyshorteners
# Successfully installed pyshorteners-1.0.1

# %%
# Wikipedia version with 2 summaries and URLs tabulated in a table format
import requests
from transformers import pipeline
import pyshorteners
from tabulate import tabulate

keywords = [
    'importance of X',
    'ideal behavior of X',
    'ideal vs. realistic behavior of X',
    'significance of X',
    'applications of X',
    'physical significance of X',
    'geometry for the measurement of X',
    'typical characteristics of X',
    'with and without X',
    'what does X represent?',
    'what is the concept of X?',
    'taxonomy of X',
    'table of X terms',
    'the analog of X',
    'physical meaning of X',
    'X symbolism',
    'iconographic meaning of X',
    'why is X important?',
    'generic model of a X',
    'drawbacks of X',
    'limitations of X',
    'advantages of X',
    'X table',
    'table of X',
    'X is related to?',
    'linear model of X',
    'schematic representation of X',
    'generic model of a X',
    'generic model of an X',
    'generic model representation of X',
    'floor plan of X',
    'trajectory of X',
    'motivation for X',
    'open-source alternatives for X',
    'visual guide to X',
    'audio guide to X',
    'roadmap of X',
    'summary of X',
    'meaning and significance of X',
    'meaning, significance, and limitations of X',
    'please provide some critical equations and formulas for understanding X and demonstrate an example with Python code. Plot the output.'
]

base_url = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "",
    "srprop": "snippet"
}

entry = input("Enter the word for X: ")

summarizer = pipeline("summarization")
shortener = pyshorteners.Shortener()

table_data = []

for keyword in keywords:
    keyword_with_entry = keyword.replace("X", entry)
    params["srsearch"] = keyword_with_entry
    response = requests.get(base_url, params=params).json()
    results = response["query"]["search"]
    if len(results) > 0:
        row = [keyword_with_entry]
        for i, result in enumerate(results[:2]):
            title = result["title"]
            snippet = result["snippet"]
            summary = summarizer(snippet, max_length=100, min_length=30, do_sample=False)[0]['summary_text']
            page_url = f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"
            shortened_url = shortener.tinyurl.short(page_url)
            row.extend([summary, shortened_url])
        table_data.append(row)

table_headers = ["Keyword", "Summary 1", "URL 1", "Summary 2", "URL 2"]
table = tabulate(table_data, headers=table_headers, tablefmt="pipe")

print(table)
# Out:
# Enter the word for X: Navajo linguistics
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 47. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 100, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 100, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 71. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# | Keyword                                                      | Summary 1                                                                                                                                                                                                                                                                                                   | URL 1                        | Summary 2                                                                                                                                                                                                                                                                                     | URL 2                        |
# |:-------------------------------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|
# | importance of Navajo linguistics                             | Among the Mayan languages, Yucatec (with the largest number <span class="searchmatch">of</span> speakers) and the Oto-Manguean languages (including Navajo) are mostly non-tonal .                                                                                                                          | https://tinyurl.com/yag2wcn4 | The branch studies how languages systematically organize their phones or, for sign languages, their constituent parts . The branch is the branch <span class="searchmatch">of <span>linguistics .                                                                                             | https://tinyurl.com/6mooo4e  |
# | ideal behavior of Navajo linguistics                         | Athabaskan language–speaking peoples of the Southwest and the Southern Plains . They are linguistically related to the <span class="searchmatch">Navajo .                                                                                                                                                   | https://tinyurl.com/yam2l6uk | Used for women in relation to their sexual identity or sexual . identity or . sexual . orientation, regardless of sexual orientation, or as an adjective to characterize or associate . Adjective used to describe or associate women's behavior or sexual identity .                         | https://tinyurl.com/mfhtpdt  |
# | significance of Navajo linguistics                           | The phonology of the language is intimately connected to its morphology . The entire range <span class="searchmatch">of contrastive consonants is used in the sound system .                                                                                                                                | https://tinyurl.com/22g59alb | Among the Mayan languages, Yucatec (with the largest number <span class="searchmatch">of</span> speakers) and the Oto-Manguean languages (including Navajo) are mostly non-tonal .                                                                                                            | https://tinyurl.com/yag2wcn4 |
# | applications of Navajo linguistics                           | Journal of Journal of Linguistics 35 (3): 213–219. Young, Robert W., &amp; Morgan, William Sr. (1987). The <span class="searchmatch">Navajo</span> language: Navajo .                                                                                                                                       | https://tinyurl.com/y8gw2jsq | inversion in <span class="searchmatch">Navajo</span>. In B. Kachru, R. B. Lees, Y. Malkiel, A. Pietrangeli, &amp; S. Saporta (eds.) Papers in honor of Renée Henry and Renée .                                                                                                                | https://tinyurl.com/2yagk9e4 |
# | physical significance of Navajo linguistics                  | Ethnomusicology has been defined by ethnomusicism, music theory and music theory . Ethnomistsicology includes anthropology, musicology, comparative musicology and history . Music theory and history have been defined as music theory, theory, music history, music science and ethnomism .               | https://tinyurl.com/2arpfc7a | The terminological shift draws attention to the field's grounding in anthropology . The field is now known as "linguistic anthropology" instead of the "anthropological" subfield .                                                                                                           | https://tinyurl.com/25r5sazd |
# | geometry for the measurement of Navajo linguistics           | Pluto's mass is roughly 0.2% that of Earth, and far too small to account . Pluto's moon Charon allowed <span class="searchmatch">the</span> first time: roughly 0 .2% of Earth's mass .                                                                                                                     | https://tinyurl.com/7lfltno  | Often <span class="searchmatch">the</span> abbreviation used <span> for <span searchmatch" and the singular is used also as a plural . This is normal for most units, currency and most units .                                                                                               | https://tinyurl.com/yavuyn5p |
# | typical characteristics of Navajo linguistics                | Navajo has a limited number <span class="searchmatch">of </span> labial sounds, both in terms of articulation and less at other places .                                                                                                                                                                    | https://tinyurl.com/22g59alb | Among the Mayan languages, Yucatec (with the largest number <span class="searchmatch">of</span> speakers) and the Oto-Manguean languages (including Navajo) are mostly non-tonal .                                                                                                            | https://tinyurl.com/yag2wcn4 |
# | with and without Navajo linguistics                          | Diné bizaad [tìnépìz̥ɑ̀ːt] is a Southern Athabaskan language .                                                                                                                                                                                                                                                | https://tinyurl.com/j5vymdg  | <span class="searchmatch">Navajo</span> is a &quot;verb-heavy language . It has a great preponderance of verbs but relatively few nouns .                                                                                                                                                     | https://tinyurl.com/2ylmpd7h |
# | what does Navajo linguistics represent?                      | Kari, James. 1989. Journal of American <span class="searchmatch">Linguistics 23(4). 291–97. Affix positions and zones in the Athapaskan verb complex: Ahtna and Navajo .                                                                                                                                    | https://tinyurl.com/2bcsh58p | Proto-Athabascan *-ɢʊtʼ ('knee') is toneless -ɢotʼ in Hupa, low-tone -ɡòd in <span class="searchmatch">Navajo" and high-tone tó in Slavey .                                                                                                                                                   | https://tinyurl.com/yag2wcn4 |
# | what is the concept of Navajo linguistics?                   | Athabaskan is an anglicized version of a Cree word . Navajo is spoken by the largest number of people north of Mexico .                                                                                                                                                                                     | https://tinyurl.com/2bcsh58p | Phonology studies how languages systematically organize their phones or, for sign languages, their constituent parts <span class="searchmatch">of </span> signs .                                                                                                                             | https://tinyurl.com/6mooo4e  |
# | taxonomy of Navajo linguistics                               | Navajo or Navaho is a Southern Athabaskan language . Diné bizaad [tìnépìz̥ɑ̀ːt] or Naabeehóbizaad is the language of the Athabasan . Navajo is the name of the Native American tribe .                                                                                                                        | https://tinyurl.com/j5vymdg  | A genealogical link between Old World and New World language families that meets the standards of traditional comparative-historical <span class="searchmatch">linguistics .                                                                                                                  | https://tinyurl.com/26gddg55 |
# | table of Navajo linguistics terms                            | Navajo has a limited number <span class="searchmatch">of </span> labial sounds, both in terms and in terms of terms . It has a few coronal places and less at other places .                                                                                                                                | https://tinyurl.com/22g59alb | Among the Mayan languages, Yucatec (with the largest number <span class="searchmatch">of</span> speakers) and the Oto-Manguean languages (including Navajo) are mostly non-tonal .                                                                                                            | https://tinyurl.com/yag2wcn4 |
# | the analog of Navajo linguistics                             | She was the first UCSD student ever to write two dissertations on English and Navajo . She created <span class="searchmatch">the <span> engineered language .                                                                                                                                               | https://tinyurl.com/lon2e9p  | From multiple other languages, including Hebrew, Latin, Latin and Chakobsa, the Nahuatl language . The language is of the Aztecs, Greek, Persian, Persian and East Indian, Russian, Turkish . Hebrew, <span class="searchmatch">Navajo</span>                                                 | https://tinyurl.com/ovolyh3  |
# | physical meaning of Navajo linguistics                       | Navajo or Navaho is a Southern Athabaskan language . Diné bizaad [tìnépìz̥ɑ̀ːt] or Naabeehóbizaad is the language of the Athabasan . Navajo is the name of the Native American tribe .                                                                                                                        | https://tinyurl.com/j5vymdg  | <span class="searchmatch">Navajo is a &quot;verb-heavy language . It has a great preponderance of verbs but relatively few nouns . In addition to verbs and nouns, the language has other elements .                                                                                          | https://tinyurl.com/2ylmpd7h |
# | Navajo linguistics symbolism                                 | Co-authored with Adolph Bitanny, co-authored the story of the Coeur d'Alene . Hail Chant: Composition and <span class="searchmatch">Symbolism</span> of the Ceirdene . Co-author: The Story of the Native Americans .                                                                                       | https://tinyurl.com/27w49wtp | Anasazi is a word that means Ancient Ones or Ancient Enemy, hence Pueblo peoples' rejection of the word . to ancestral Pueblos people . Anaszi is a <span class="searchmatch">Navajo</span> word .                                                                                            | https://tinyurl.com/2cc85csp |
# | visual guide to Navajo linguistics                           | Phonology studies how languages systematically organize their phones or, for sign languages, their constituent parts . Phonologists study how languages arrange their phones .                                                                                                                              | https://tinyurl.com/6mooo4e  | The largest Native American language-speaking community by far is the <span class="searchmatch">Navajo</span>. Navajo is an Athabaskan .                                                                                                                                                      | https://tinyurl.com/npnnnnx  |
# | audio guide to Navajo linguistics                            | Diné bizaad [tìnépìz̥ɑ̀ːt] is a Southern Athabaskan language .                                                                                                                                                                                                                                                | https://tinyurl.com/j5vymdg  | California Studies in <span class="searchmatch">Linguistics . vol. 29. Berkeley: California UP. 76-101. How Different can Languages be?                                                                                                                                                       | https://tinyurl.com/24yua8h4 |
# | roadmap of Navajo linguistics                                | Notes included a description of the story and a great deal of character background information . 'But having a <span class="searchmatch">roadmap">road map of the U.S. and actually driving actually driving'                                                                                               | https://tinyurl.com/ovolyh3  | Diana Gabaldon is the author and creator of the Outlander franchise . Jonathan Nez is the 9th President of the Navajo Nation . Lopez Lomong is South Sudanese-born and South Sudanian-born .                                                                                                  | https://tinyurl.com/yuko534b |
# | summary of Navajo linguistics                                | Among the Mayan languages, Yucatec (with the largest number <span class="searchmatch">of</span> speakers) and the Oto-Manguean languages (including Navajo) are mostly non-tonal .                                                                                                                          | https://tinyurl.com/yag2wcn4 | The proposed Dene-Yeniseian connection cannot be embraced . In <span class="searchmatch">Kari and Potter’s <span> journal 77:445-451 .                                                                                                                                                        | https://tinyurl.com/26gddg55 |
# | meaning and significance of Navajo linguistics               | This article is about the sound system <span class="searchmatch">of the <span searchmatch" language . The phonology of the language is the phonological system .                                                                                                                                            | https://tinyurl.com/22g59alb | Tone is the use of pitch in language to distinguish lexical or grammatical <span class="searchmatch">meaning . / / / and . ⟨ ⟩, see IPA § Bracket .                                                                                                                                           | https://tinyurl.com/yag2wcn4 |
# | meaning, significance, and limitations of Navajo linguistics | This includes a wide variety of disciplines such as folklore, psychology, cultural anthropology and cultural anthropology . Music theory, comparative musicology, music theory and music theory .                                                                                                           | https://tinyurl.com/2arpfc7a | Extreme Intentionalism holds that authorial. subject matter and content is authorial . Others prefer terms like <span class="searchmatch">meaning <span> and <span class="Searchmatch">and</span> connotations . Extreme intentalism is a form of extreme intentality .                       | https://tinyurl.com/d89fdfq  |

# %%
# Wikipedia version with 2 summaries and URLs tabulated in a table format
import requests
from transformers import pipeline
import pyshorteners
from tabulate import tabulate

keywords = [
    'importance of X',
    'ideal behavior of X',
    'ideal vs. realistic behavior of X',
    'significance of X',
    'applications of X',
    'physical significance of X',
    'geometry for the measurement of X',
    'typical characteristics of X',
    'with and without X',
    'what does X represent?',
    'what is the concept of X?',
    'taxonomy of X',
    'table of X terms',
    'the analog of X',
    'physical meaning of X',
    'X symbolism',
    'iconographic meaning of X',
    'why is X important?',
    'generic model of a X',
    'drawbacks of X',
    'limitations of X',
    'advantages of X',
    'X table',
    'table of X',
    'X is related to?',
    'linear model of X',
    'schematic representation of X',
    'generic model of a X',
    'generic model of an X',
    'generic model representation of X',
    'floor plan of X',
    'trajectory of X',
    'motivation for X',
    'open-source alternatives for X',
    'visual guide to X',
    'audio guide to X',
    'roadmap of X',
    'summary of X',
    'meaning and significance of X',
    'meaning, significance, and limitations of X',
    'please provide some critical equations and formulas for understanding X and demonstrate an example with Python code. Plot the output.'
]

base_url = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "",
    "srprop": "snippet"
}

entry = input("Enter the word for X: ")

summarizer = pipeline("summarization")
shortener = pyshorteners.Shortener()

table_data = []

for keyword in keywords:
    keyword_with_entry = keyword.replace("X", entry)
    params["srsearch"] = keyword_with_entry
    response = requests.get(base_url, params=params).json()
    results = response["query"]["search"]
    if len(results) > 0:
        row = [keyword_with_entry]
        for i, result in enumerate(results[:2]):
            title = result["title"]
            snippet = result["snippet"]
            summary = summarizer(snippet, max_length=100, min_length=30, do_sample=False)[0]['summary_text']
            page_url = f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"
            shortened_url = shortener.tinyurl.short(page_url)
            row.extend([summary, shortened_url])
        table_data.append(row)

table_headers = ["Keyword", "Summary 1", "URL 1", "Summary 2", "URL 2"]
table = tabulate(table_data, headers=table_headers, tablefmt="pipe")

print(table)
# Out:
# Enter the word for X: Navajo language
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Your max_length is set to 100, but your input_length is only 86. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 100, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 86. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 100, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 94. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 78. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 86. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 100, but your input_length is only 71. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# | Keyword                                                   | Summary 1                                                                                                                                                                                                                                                                            | URL 1                        | Summary 2                                                                                                                                                                                                                                                                                                                                                      | URL 2                        |
# |:----------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|
# | importance of Navajo language                             | The <span class="searchmatch">Navajo</span> Reservation is slightly larger than the state of West Virginia . The reservation is located in Arizona, Utah, and New Mexico .                                                                                                           | https://tinyurl.com/wyz22v8  | Contestants must be unmarried, over 18 years <span class="searchmatch">of</span> age, be a high school graduate, and be able to speak Navajo . Contestants compete in such activities as answering questions .                                                                                                                                                 | https://tinyurl.com/2agg7jcq |
# | ideal behavior of Navajo language                         | Navajo medicine dates back thousands of years as many as many Navajo people . Medicine covers a range <span class="searchmatch">of traditional healing practices .                                                                                                                   | https://tinyurl.com/29kdx3xt | Southern Athabaskan <span class="searchmatch">language</span>–speaking peoples of the Southwest and the Southern Plains . They are linguistically related to the <span>Navajo Navajo . They migrated from the South to the South .                                                                                                                             | https://tinyurl.com/yam2l6uk |
# | ideal vs. realistic behavior of Navajo language           | Peter Iverson, Diné: A History <span class="searchmatch">of</span> the <span>Navajos, Illinois Press. pp.113–15. ISBN 9780252012853.                                                                                                                                                 | https://tinyurl.com/hd7bbaw  | Samoan, Hawaiian, Navajo, Cherokee, Cherokee and Sioux are the most common native languages . Native languages include Samoan and Hawaiian . Indigenous languages include Inuit, Native American and Inuit .                                                                                                                                                   | https://tinyurl.com/thje3fd  |
# | significance of Navajo language                           | The phonology <span class="searchmatch">of </span> the <span>Navajo</span> language is intimately connected to its morphology . For example, the entire range of contrastive consonants can be found in Navajo .                                                                     | https://tinyurl.com/22g59alb | The summit is the highest point on the <span class="searchmatch">Navajo</span> Nation . It is a prominent free-standing mountain .                                                                                                                                                                                                                             | https://tinyurl.com/22pjhyax |
# | audio guide to Navajo language                            | Navajo or Navaho is a Southern Athabaskan . Navajo is the language of the Athabasan of the Navajo people . Diné bizaad [tìnépìz̥ɑ̀ːt] or Naabeehó [nævəhoʊ,  ˈnɑː-/; . Navaho (Navaho) is the name of the Native Americans who live in                                                 | https://tinyurl.com/j5vymdg  | Manuelito spoke <span class="searchmatch">Navajo</span> and is famous for his leadership during and after the Long Walk of the Navajo . The seven Southern Athabaskan languages can be divided .                                                                                                                                                               | https://tinyurl.com/24yua8h4 |
# | roadmap of Navajo language                                | In addition to Arabic, Dune derives words and names from multiple other languages, including Hebrew, Hebrew, Navajo, Latin and Latin .                                                                                                                                               | https://tinyurl.com/ovolyh3  | Yootó Hahoodzo <span class="searchmatch">Navajo</span> is a state in the Southwestern United States . It is one of the Mountain States .                                                                                                                                                                                                                       | https://tinyurl.com/6j2bsja  |
# | summary of Navajo language                                | The <span class="searchmatch">Navajo</span> Reservation is slightly larger than the state of West Virginia . The reservation is located in Arizona, Utah, and New Mexico .                                                                                                           | https://tinyurl.com/wyz22v8  | The winner represents the <span class="searchmatch">Navajo</span> Nation, with the winner representing the culture and serving as a role model and role model .                                                                                                                                                                                                | https://tinyurl.com/25rjg2en |
# | meaning and significance of Navajo language               | This article is about the sound system <span class="searchmatch">of the <span>Navajo</span> language . The phonology of the language is that the phonology is that of Navajo .                                                                                                       | https://tinyurl.com/22g59alb | The lack of a word for radiation in the <span class="searchmatch">Navajo</span> language left the miners unaware of the associated health hazards .                                                                                                                                                                                                            | https://tinyurl.com/hxcz7sh  |
# | meaning, significance, and limitations of Navajo language | Hall proposed a similar difference between <span class="searchmatch">Navajo <span>-speakers in a United States school and English speakers in a U.S. school . He proposed a &quot;spectrum&quot ; of national cultures from . national cultures .                                    | https://tinyurl.com/ybv8deec | Extreme Intentionalism holds that authorial. subject matter and content is authorial . Others prefer terms like <span class="searchmatch">meaning <span> and <span class="Searchmatch">and</span> connotations . Extreme intentalism is a form of extreme intentality .                                                                                        | https://tinyurl.com/d89fdfq  |

# %%
# Wikipedia version with 2 summaries and URLs tabulated in a table format
import requests
from transformers import pipeline
import pyshorteners
from tabulate import tabulate

keywords = [
    'importance of X',
    'ideal behavior of X',
    'ideal vs. realistic behavior of X',
    'significance of X',
    'applications of X',
    'physical significance of X',
    'geometry for the measurement of X',
    'typical characteristics of X',
    'with and without X',
    'what does X represent?',
    'what is the concept of X?',
    'taxonomy of X',
    'table of X terms',
    'the analog of X',
    'physical meaning of X',
    'X symbolism',
    'iconographic meaning of X',
    'why is X important?',
    'generic model of a X',
    'drawbacks of X',
    'limitations of X',
    'advantages of X',
    'X table',
    'table of X',
    'X is related to?',
    'linear model of X',
    'schematic representation of X',
    'generic model of a X',
    'generic model of an X',
    'generic model representation of X',
    'floor plan of X',
    'trajectory of X',
    'motivation for X',
    'open-source alternatives for X',
    'visual guide to X',
    'audio guide to X',
    'roadmap of X',
    'summary of X',
    'meaning and significance of X',
    'meaning, significance, and limitations of X',
    'please provide some critical equations and formulas for understanding X and demonstrate an example with Python code. Plot the output.'
]

base_url = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "",
    "srprop": "snippet"
}

entry = input("Enter the word for X: ")

summarizer = pipeline("summarization")
shortener = pyshorteners.Shortener()

table_data = []

for keyword in keywords:
    keyword_with_entry = keyword.replace("X", entry)
    params["srsearch"] = keyword_with_entry
    response = requests.get(base_url, params=params).json()
    results = response["query"]["search"]
    if len(results) > 0:
        row = [keyword_with_entry]
        for i, result in enumerate(results[:2]):
            title = result["title"]
            snippet = result["snippet"]
            summary = summarizer(snippet, max_length=100, min_length=30, do_sample=False)[0]['summary_text']
            page_url = f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"
            shortened_url = shortener.tinyurl.short(page_url)
            row.extend([summary, shortened_url])
        table_data.append(row)

table_headers = ["Keyword", "Summary 1", "URL 1", "Summary 2", "URL 2"]
table = tabulate(table_data, headers=table_headers, tablefmt="pipe")

print(table)
# Out:
# Enter the word for X: Navajo Cyrillic
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Your max_length is set to 100, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 100, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 100, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 100, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 71. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 100, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 94. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 100, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 100, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 100, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# | Keyword                                      | Summary 1                                                                                                                                                                                                                                                        | URL 1                        | Summary 2                                                                                                                                                                                                                                                                      | URL 2                        |
# |:---------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|
# | importance of Navajo Cyrillic                | TRANSLITERATION TABLES FOR NORTHERN MANSI: Counterparts <span class="searchmatch">of <span>Cyrillic</span> FUT Counterparts and IPA characters for Northern Mansi .                                                                                              | https://tinyurl.com/yu2ox9yv | Aztec and Navajo inspired patterns featured diamonds and triangles . Timberland Company hiking boots were popular trends in early and mid 2010s . Other popular trends included Aztec, Navajo and Navajo patterns .                                                            | https://tinyurl.com/y4rxks28 |
# | ideal behavior of Navajo Cyrillic            | Aztec and Navajo inspired patterns featured diamonds and triangles . Timberland Company hiking boots were popular trends in early and mid 2010s . Other popular trends included Aztec, Navajo and Navajo patterns .                                              | https://tinyurl.com/y4rxks28 |                                                                                                                                                                                                                                                                                |                              |
# | applications of Navajo Cyrillic              | languages with alphabets based on the Latin, <span class="searchmatch">Cyrillic</span> and Greek scripts . For the most commonly encountered uses of the accent in the Latin and Greek alphabetets, the accent is used in many of the world's languages .        | https://tinyurl.com/o2o4h6k  | Google Translate supports 133 languages at various levels . It claimed over 500 million total users as <span class="searchmatch">of </span> April 2016 .                                                                                                                       | https://tinyurl.com/yym9xwls |
# | typical characteristics of Navajo Cyrillic   | The alphabet was in turn the basis of the Etruscan and Coptic alphabets, notably the Coptic and Armenian, Gothic, and Cyrillic . Similar arguments can be derived .                                                                                              | https://tinyurl.com/y99vsqkw | System similar to Greek numerals, including Hebrew numerals and Cyrillic numerals . system similar to system . system . Also known as Hebrew gematria and Abjad numerals. system .                                                                                             | https://tinyurl.com/7utkc4z  |
# | with and without Navajo Cyrillic             | L is a letter of the Polish, Kashubian, Sorbian, Belarusian Latin, Ukrainian Latin, Wymysorys, Navajo, Dëne Sųłıné, Inupiaq . described in English as L <span class="searchmatch">with</span> stroke .                                                           | https://tinyurl.com/yrg2n82j | Norwegian, Swedish and Danish use the acute accent to indicate that a terminal syllable with the e is more pronounced . The acute marks a higher tone in Norwegian and Swedish .                                                                                               | https://tinyurl.com/o2o4h6k  |
# | what does Navajo Cyrillic represent?         | Dutch, Faroese, Filipino, Galician, Hungarian, Icelandic, Irish, Lakota, Occitan, Portuguese, Sámi, Slovak, Spanish, Vietnamese, Welsh, and Western .                                                                                                            | https://tinyurl.com/ynvmq8kv | ⟨ć⟩ is used to represent a voiceless alveolo-palatal affricate /t͡ɕ/. In the romanization of Macedonian, the letters are used to refer to the Cyrillic letters Gje and Gje .                                                                                                    | https://tinyurl.com/o2o4h6k  |
# | what is the concept of Navajo Cyrillic?      | The acute accent is a diacritic used in many modern written languages with alphabets based on Latin, Cyrillic, and Greek .                                                                                                                                       | https://tinyurl.com/o2o4h6k  | Sonya Sonya. Sonya . (2001) &quot;<span class="searchmatch">What</span> is a word? Evidence from a computational approach to <span class"searchmatch" Navajo's verbal morphology .                                                                                             | https://tinyurl.com/hdjoj4n  |
# | taxonomy of Navajo Cyrillic                  | Ket and Navajo are inalienable nouns attached with the prefix a-, which means &quot;someone's&quot ;someone's .quotie. is a table of words .                                                                                                                     | https://tinyurl.com/26gddg55 |                                                                                                                                                                                                                                                                                |                              |
# | table of Navajo Cyrillic terms               | Ket and Navajo are inalienable nouns attached with the prefix a-, which means &quot;someone's&quot ;. Someone's . The words Ket, Navajo, and Ket are used for settlement in the Americas .                                                                       | https://tinyurl.com/26gddg55 | CATEGORIES TRANSLITERATION FOR NORTHERN MANSI: Counterparts <span class="searchmatch">of <span> of <span Cyrillic</span> Counterparts for Northern Mansi: FUT Counterparts Counterparts . Counterparts and IPA characters are translated into words for the Northern Manians . | https://tinyurl.com/yu2ox9yv |
# | the analog of Navajo Cyrillic                | The same holds <span class="searchmatch">analogically for ⟨ε⟩ and ⟟��ά, which must have been [eː), and so on. stage . For <span class="Searchmatch">the</span> consonants, historical linguistics established <span> the original stage of the consonant stage . | https://tinyurl.com/y99vsqkw | <span class="searchmatch">Cyrillic, Abjad numerals, also Hebrew gematria and Greek isopsephy). The dots are assigned in no obvious order .                                                                                                                                     | https://tinyurl.com/7utkc4z  |
# | physical meaning of Navajo Cyrillic          | In some languages vowel length is an important phonemic factor in some languages . The corresponding length is the length of a vowel sound: the corresponding measurement is duration .                                                                          | https://tinyurl.com/yu2ox9yv | U.S. was still assigning rural addresses as <span class="searchmatch">of 2015 and the lack of rural addresses can be used for countries . For example, the Navajo Nation in the United States still assigned rural addresses .                                                 | https://tinyurl.com/qozuok8  |
# | Navajo Cyrillic symbolism                    | The Bulgarian version of the pastry is locally called byurek . It is typically regarded as a variation of banitsa (баница), a similar pastry .                                                                                                                   | https://tinyurl.com/gq56xt5  |                                                                                                                                                                                                                                                                                |                              |
# | generic model of a Navajo Cyrillic           | I • Neal Koblitz • Needham–Schroeder protocol • Negligible function • NEMA . NEMA • National Security Agency • National Cipher Challenge .                                                                                                                       | https://tinyurl.com/9y6royh  |                                                                                                                                                                                                                                                                                |                              |
# | generic model of an Navajo Cyrillic          | I • Neal Koblitz • Needham–Schroeder protocol • Negligible function • NEMA . NEMA • National Security Agency • National Cipher Challenge .                                                                                                                       | https://tinyurl.com/9y6royh  |                                                                                                                                                                                                                                                                                |                              |
# | floor plan of Navajo Cyrillic                | U.S. was still assigning rural addresses as <span class="searchmatch">of 2015 and the lack of rural addresses can be used for countries . For example, the Navajo Nation in the United States still assigned rural addresses .                                   | https://tinyurl.com/qozuok8  | Aztec and Navajo inspired patterns featured diamonds and triangles . Timberland Company hiking boots were popular trends in early and mid 2010s . Other popular trends included Aztec, Navajo and Navajo patterns .                                                            | https://tinyurl.com/y4rxks28 |
# | open-source alternatives for Navajo Cyrillic | Texts written in the Arabic, Cyrillic, Devanagari and Greek scripts can be transliterated . Results from the selected destination language in the <span class="searchmatch">source</span> language .                                                             | https://tinyurl.com/yym9xwls | Modern written languages with alphabets based on the Latin, Cyrillic, and Greek scripts use the Latin accent . The accent accent is used in many of the most commonly encountered uses of the accent in Latin .                                                                | https://tinyurl.com/o2o4h6k  |
# | visual guide to Navajo Cyrillic              | A representational system can be said <span class="searchmatch">to </span> be an appropriate orthography . are correctly rendered so as to maintain the Lojbanic audio-<span> visual-visual visual isomorphism .                                                 | https://tinyurl.com/q8dc4b7  |                                                                                                                                                                                                                                                                                |                              |
# | audio guide to Navajo Cyrillic               | Ukrainian, Navajo, Tagalog, and Estonian voice actors faced difficulty in finding voice actors and developing a unique identity for the language .                                                                                                               | https://tinyurl.com/okkqd8m  | Russian Empire had contact with Alaska and the coast of North America down <span class="searchmatch">to</span> Sonoma County .                                                                                                                                                 | https://tinyurl.com/hdjoj4n  |
# | summary of Navajo Cyrillic                   | Ket and Navajo are inalienable nouns attached with the prefix a-, which means &quot;someone's&quot ;someone's .quotie. is a table of words .                                                                                                                     | https://tinyurl.com/26gddg55 | I • Neal Koblitz • Needham–Schroeder protocol • Negligible function • NEMA . NEMA • National Security Agency • National Cipher Challenge .                                                                                                                                     | https://tinyurl.com/9y6royh  |

# %%
# Wikipedia version with 2 summaries and URLs tabulated in a table format
import requests
from transformers import pipeline
import pyshorteners
from tabulate import tabulate

keywords = [
    'importance of X',
    'ideal behavior of X',
    'ideal vs. realistic behavior of X',
    'significance of X',
    'applications of X',
    'physical significance of X',
    'geometry for the measurement of X',
    'typical characteristics of X',
    'with and without X',
    'what does X represent?',
    'what is the concept of X?',
    'taxonomy of X',
    'table of X terms',
    'the analog of X',
    'physical meaning of X',
    'X symbolism',
    'iconographic meaning of X',
    'why is X important?',
    'generic model of a X',
    'drawbacks of X',
    'limitations of X',
    'advantages of X',
    'X table',
    'table of X',
    'X is related to?',
    'linear model of X',
    'schematic representation of X',
    'generic model of a X',
    'generic model of an X',
    'generic model representation of X',
    'floor plan of X',
    'trajectory of X',
    'motivation for X',
    'open-source alternatives for X',
    'visual guide to X',
    'audio guide to X',
    'roadmap of X',
    'summary of X',
    'meaning and significance of X',
    'meaning, significance, and limitations of X',
    'please provide some critical equations and formulas for understanding X and demonstrate an example with Python code. Plot the output.'
]

base_url = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "",
    "srprop": "snippet"
}

entry = input("Enter the word for X: ")

summarizer = pipeline("summarization")
shortener = pyshorteners.Shortener()

table_data = []

for keyword in keywords:
    keyword_with_entry = keyword.replace("X", entry)
    params["srsearch"] = keyword_with_entry
    response = requests.get(base_url, params=params).json()
    results = response["query"]["search"]
    if len(results) > 0:
        row = [keyword_with_entry]
        for i, result in enumerate(results[:2]):
            title = result["title"]
            snippet = result["snippet"]
            summary = summarizer(snippet, max_length=100, min_length=30, do_sample=False)[0]['summary_text']
            page_url = f"https://en.wikipedia.org/wiki/{title.replace(' ', '_')}"
            shortened_url = shortener.tinyurl.short(page_url)
            row.extend([summary, shortened_url])
        table_data.append(row)

table_headers = ["Keyword", "Summary 1", "URL 1", "Summary 2", "URL 2"]
table = tabulate(table_data, headers=table_headers, tablefmt="pipe")

print(table)
# Out:
# Enter the word for X: Navajo alphabet
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 100, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 100, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 100, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 100, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 42. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 100, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 100, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 100, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 100, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 100, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 100, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 100, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 100, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 100, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 100, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 100, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 100, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 100, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 100, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 47. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 100, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 100, but your input_length is only 71. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 100, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 100, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 100, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 100, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# | Keyword                                         | Summary 1                                                                                                                                                                                                                                                          | URL 1                        | Summary 2                                                                                                                                                                                                                                                          | URL 2                        |
# |:------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------|
# | importance of Navajo alphabet                   | In 1824, at the age of 15, he developed the braille code based on the French <span class="searchmatch">alphabet . He published the code as an improvement on night writing .                                                                                       | https://tinyurl.com/7utkc4z  | Polish, <span class="searchmatch">Navajo</span> and Elfdalian use a hook under the letter . In the standardized orthographies most varieties of Tupí-Guaraní are spoken in Bolivia .                                                                               | https://tinyurl.com/ype8rh24 |
# | ideal behavior of Navajo alphabet               | Four <span class="searchmatch">ideal</span> time zones had north–south borders, the first centered on Washington, D.C., but by 1872 the first was centered on meridian 75° west of Greenwich .                                                                     | https://tinyurl.com/3n4gemd  | Coronet Films was an educational film company from the 1940s through the 1990s . This is an alphabetical list of major titles produced by Coronet films .                                                                                                          | https://tinyurl.com/yp82rzls |
# | significance of Navajo alphabet                 | The phonology of the language is intimately connected to its morphology . The entire range <span class="searchmatch">of contrastive consonants is used in the sound system .                                                                                       | https://tinyurl.com/22g59alb | This article contains phonetic transcriptions in the International Phonetic <span class="searchmatch">Alphabet</span> (IPA) For an introductory guide on IPA symbols, see Help:IPA .                                                                               | https://tinyurl.com/yag2wcn4 |
# | applications of Navajo alphabet                 | Nunavut and the Northwest Territories use a Latin-script usually identified as Inuinnaqtun . In Alaska, another Latin <span class="searchmatch">alphabet</span> is used .                                                                                          | https://tinyurl.com/pw9j4l8  | Google Translate supports 134 languages at various levels . It claimed over 500 million total users as <span class="searchmatch">of </span> April 2016 .                                                                                                           | https://tinyurl.com/yym9xwls |
# | physical significance of Navajo alphabet        | Navajo people see nature as a source of beauty and inspiration . Many patterns and symbols in <span class="searchmatch">Navajo</span> art are drawn from nature .                                                                                                  | https://tinyurl.com/yrbc8jaa | pērkonkrusts ('cross <span class="searchmatch">of</span> thunder', 'thunder cross') can denote abundance of thunder .                                                                                                                                              | https://tinyurl.com/bppdhyz  |
# | geometry for the measurement of Navajo alphabet | Back catalogue of films made earlier were reissued under Coronet banner . It was quite common <span class="searchmatch">for a film to be re-released as a &quot;2nd .                                                                                              | https://tinyurl.com/yp82rzls | The International Phonetic <span class="searchmatch">Alphabet</span> (IPA) is an introductory guide on IPA symbols, see Help:IPA. phonetic transcriptions .                                                                                                        | https://tinyurl.com/yavuyn5p |
# | typical characteristics of Navajo alphabet      | Navajo has a limited number <span class="searchmatch">of </span> labial sounds, both in terms of articulation and less at other places .                                                                                                                           | https://tinyurl.com/22g59alb | In 1824, at the age of 15, he developed the braille code based on the French <span class="searchmatch">alphabet . He published the code as an improvement on night writing .                                                                                       | https://tinyurl.com/7utkc4z  |
# | with and without Navajo alphabet                | The code used <span class="searchmatch">Navajo</span> words for each letter of the English alphabet . remained unbroken . Messages could be encoded by using a simple substitution .                                                                               | https://tinyurl.com/j5vymdg  | Meskwaki, <span class="searchmatch">and</span> peoples. used words from their languages for each letter of the English . Messages could be encoded by decoded by using words from each letter from each of their languages .                                       | https://tinyurl.com/p9susfa  |
# | what does Navajo alphabet represent?            | Comanche, Hopi, Meskwaki, and <span class="searchmatch">Navajo peoples used words from their languages for each letter of the English alphabet . Messages could be encoded and encoded .                                                                           | https://tinyurl.com/p9susfa  | In 1888, the <span class="searchmatch">alphabet was revised to be uniform . It was originally represented with the letter ⟨c in English, but with the digraph in French .                                                                                          | https://tinyurl.com/c2ph4xk  |
# | what is the concept of Navajo alphabet?         | The Comanche, Hopi, Meskwaki, and Navajo peoples. used words from their languages for each letter . The words were used on each letter of the alphabet .                                                                                                           | https://tinyurl.com/p9susfa  | International Phonetic (IPA) is an alphabetic system based primarily on the Latin script . It is based on the IPA's system of the alphabet . The IPA uses symbols instead of the Latin alphabet .                                                                  | https://tinyurl.com/c2ph4xk  |
# | taxonomy of Navajo alphabet                     | Navajo or Navaho is a Southern Athabaskan language . Diné bizaad [tìnépìz̥ɑ̀ːt] or Naabeehóbizaad is the language of the Athabasan . Navajo is the name of the Native American tribe .                                                                               | https://tinyurl.com/j5vymdg  | Hopi, Keresan, and Tanoan (and a lesser extent <span class="searchmatch">Navajo) are probably due to language contact .                                                                                                                                            | https://tinyurl.com/ymf4237c |
# | table of Navajo alphabet terms                  | Navajo has a limited number <span class="searchmatch">of </span> labial sounds, both in terms and in terms of terms . It has a few coronal places and less at other places .                                                                                       | https://tinyurl.com/22g59alb | The International Phonetic <span class="searchmatch">Alphabet</span> (IPA) is an alphabetic system . The IPA system is based on phonetic symbols . Boxes or other symbols are used instead of symbols .                                                            | https://tinyurl.com/c2ph4xk  |
# | the analog of Navajo alphabet                   | In 1824, at the age of 15, he developed <span class="searchmatch">the braille code based on the <span> French <span searchmatch alphabet as an improvement .                                                                                                       | https://tinyurl.com/7utkc4z  | The International Phonetic <span class="searchmatch">Alphabet</span> (IPA) For an introductory guide on IPA symbols, see Help:IPA. phonetic transcriptions .                                                                                                       | https://tinyurl.com/y99vsqkw |
# | physical meaning of Navajo alphabet             | Navajo or Navaho is a Southern Athabaskan language . Diné bizaad [tìnépìz̥ɑ̀ːt] or Naabeehóbizaad is the language of the Athabasan . Navajo is the name of the Native American tribe .                                                                               | https://tinyurl.com/j5vymdg  | G is the seventh letter of the Latin <span class="searchmatch">alphabet . G may also refer to Gabon, international license plate code G .                                                                                                                          | https://tinyurl.com/yn4oafmv |
# | Navajo alphabet symbolism                       | In Jain, it represents Suparshvanatha, the seventh of 24 Tirthankaras (spiritual teachers and saviours) In Buddhist <span class="searchmatch">symbolism</span> it represents a Buddhist symbol .                                                                   | https://tinyurl.com/bppdhyz  | Georgian Laz Mingrelian Svan Media Music Music Music Mythology Names Public holidays Religion Names . Architecture, cuisine, music, dance, movies, wine, wine and wine .                                                                                           | https://tinyurl.com/zb2z8oz  |
# | iconographic meaning of Navajo alphabet         | Among various tribes, the swastika carries different meanings . The swastika is used by southwestern tribes, most notably the Navajo, and plains nations such as the Dakota .                                                                                      | https://tinyurl.com/bppdhyz  |                                                                                                                                                                                                                                                                    |                              |
# | why is Navajo alphabet important?               | Malagasy Malay Indonesian Malaysian Malayalam Maltese Mandarin Marathi . Odia Polish Portuguese Portuguese Brazilian Portuguese European Portuguese (Português)                                                                                                    | https://tinyurl.com/yvo8ptok | Northwest Territories use a Latin-script <span class="searchmatch">alphabet </span> usually identified as Inuinnaqtun . In Alaska, another Latin is used, with some characters using diacritics .                                                                  | https://tinyurl.com/pw9j4l8  |
# | generic model of a Navajo alphabet              | The <span class="searchmatch">Navajo" emphasizes a deep connection with nature . People see nature as a source <span> of beauty and inspiration .                                                                                                                  | https://tinyurl.com/yrbc8jaa | The name chosen recalled the first letter of the Greek alphabet, intended to emphasize the beginning of the new industrial adventure . At this point, the name was the name of a new industrial venture .                                                          | https://tinyurl.com/yueupcqo |
# | limitations of Navajo alphabet                  | This article contains phonetic transcriptions in the International Phonetic <span class="searchmatch">Alphabet</span> (IPA) For an introductory guide on IPA symbols, see Help:IPA .                                                                               | https://tinyurl.com/oqkfeon  | Marwari Mazanderani Minangkabau Montenegrin Mooré (Mossi) Nagpuri (Sadri) Newar (Nepalbhasa) is Nepalese .                                                                                                                                                         | https://tinyurl.com/yym9xwls |
# | advantages of Navajo alphabet                   | The International Phonetic <span class="searchmatch">Alphabet</span> (IPA) is an alphabetic system . The IPA system is based on phonetic symbols . Boxes or other symbols are used instead of symbols .                                                            | https://tinyurl.com/c2ph4xk  | In 1824, at the age of 15, he developed the braille code based on the French <span class="searchmatch">alphabet . He published the code as an improvement on night writing .                                                                                       | https://tinyurl.com/7utkc4z  |
# | Navajo alphabet table                           | The International Phonetic system is an alphabetic system of phonetic notation . It is based on the phonetic system of the alphabet . Other symbols are used instead of phonetics symbols . The IAPA system is based primarily on the alphabet and other symbols . | https://tinyurl.com/c2ph4xk  | This article is about the sound system of the <span class="searchmatch">Navajo</span> language . The phonology of the language is intimately connected to its morphology .                                                                                         | https://tinyurl.com/22g59alb |
# | table of Navajo alphabet                        | The phonology of the language is intimately connected to its morphology . The entire range <span class="searchmatch">of contrastive consonants is used in the sound system .                                                                                       | https://tinyurl.com/22g59alb | The International Phonetic <span class="searchmatch">Alphabet</span> (IPA) is an alphabetic system . The IPA system is based on phonetic symbols . Boxes or other symbols are used instead of symbols .                                                            | https://tinyurl.com/c2ph4xk  |
# | Navajo alphabet is related to?                  | Braille uses a subset of the letters of Unified English Braille, along with the punctuation and punctuation . Braille is the braille alphabet of the <span class="searchmatch">Navajo</span> language .                                                            | https://tinyurl.com/ynu8v9yr | Na-Dené family, through which it is related to languages spoken across the western areas of North America . Navajo is spoken primarily in the Southwestern areas of the country .                                                                                  | https://tinyurl.com/j5vymdg  |
# | linear model of Navajo alphabet                 | This was widely criticized by users across a variety of social media sites . This included a range of lessons after completing previous ones, to a <span class="searchmatch">linear progression .                                                                  | https://tinyurl.com/m2xsqsx  | Phoenician <span class="searchmatch">alphabet</span> is the oldest abjad (consonantal) and the ancestor of Sardinia and Corsica as well as the island of Cyprus .                                                                                                  | https://tinyurl.com/2d34y6on |
# | schematic representation of Navajo alphabet     | Classical Nahuatl, Spanish, and occasionally Latin were used in several languages . Aztec pictograms and Latin writing are used in some of the world's most popular texts .                                                                                        | https://tinyurl.com/6u6qpey  |                                                                                                                                                                                                                                                                    |                              |
# | generic model of a Navajo alphabet              | The <span class="searchmatch">Navajo" emphasizes a deep connection with nature . People see nature as a source <span> of beauty and inspiration .                                                                                                                  | https://tinyurl.com/yrbc8jaa | The name chosen recalled the first letter of the Greek alphabet, intended to emphasize the beginning of the new industrial adventure . At this point, the name was the name of a new industrial venture .                                                          | https://tinyurl.com/yueupcqo |
# | generic model of an Navajo alphabet             | Hózhǫ́ g cannot be easily translated into a single word, but it can be understood as <span class="searchmatch">of</span> people's lives and values .                                                                                                                | https://tinyurl.com/yrbc8jaa | The name chosen recalled the first letter <span class="searchmatch">of the Greek alphabet . At this point, the name was intended to emphasize the beginning of a new industrial adventure .                                                                        | https://tinyurl.com/yueupcqo |
# | generic model representation of Navajo alphabet | Navajo people see nature as a source of beauty and inspiration . Many patterns and symbols in <span class="searchmatch">Navajo</span> art are drawn from nature .                                                                                                  | https://tinyurl.com/yrbc8jaa | In Latin American cultures, a travesti is an individual . Diné <span class="searchmatch">Navajo <span> have Nádleehi .                                                                                                                                             | https://tinyurl.com/b424y36  |
# | floor plan of Navajo alphabet                   | U.S. was still assigning rural addresses as <span class="searchmatch">of 2015 and the lack of rural addresses can be used for countries . For example, the Navajo Nation in the United States still assigned rural addresses .                                     | https://tinyurl.com/qozuok8  | pērkonkrusts ('cross <span class="searchmatch">of</span> thunder', 'thunder cross') can denote abundance of thunder .                                                                                                                                              | https://tinyurl.com/bppdhyz  |
# | trajectory of Navajo alphabet                   | This article contains phonetic transcriptions in the International Phonetic <span class="searchmatch">Alphabet</span> (IPA) For an introductory guide on IPA symbols, see Help:IPA .                                                                               | https://tinyurl.com/yu9r9j3x | Lestrade, Patricia Manning (1999). <span class="searchmatch">Trajectories in Isleño Spanish with special emphasis on the lexicon . Tuscaloosa: University of Alabama .                                                                                             | https://tinyurl.com/ys2dtyz6 |
# | motivation for Navajo alphabet                  | The International Phonetic system is an alphabetic system of phonetic notation . It is based on the phonetic system of the alphabet . Other symbols are used instead of phonetics symbols . The IAPA system is based primarily on the alphabet and other symbols . | https://tinyurl.com/c2ph4xk  | Other types of reading and writing, such as pictograms (e.g., pictograms), are a hazard . Phones are phonics, phonemic awareness, vocabulary, comprehension, fluency, and fluency .                                                                                | https://tinyurl.com/yxf5qqk5 |
# | open-source alternatives for Navajo alphabet    | Messages could be encoded and decoded by using a code used for each letter of the English alphabet . The code was used to encode and decode messages during the war .                                                                                              | https://tinyurl.com/j5vymdg  | The International Phonetic system is an alphabetic system of phonetic notation . It is based on the phonetic system of the alphabet . Other symbols are used instead of phonetics symbols . The IAPA system is based primarily on the alphabet and other symbols . | https://tinyurl.com/c2ph4xk  |
# | visual guide to Navajo alphabet                 | The International Phonetic system is an alphabetic system of phonetic notation . It is based on the phonetic system of the alphabet . Other symbols are used instead of phonetics symbols . The IAPA system is based primarily on the alphabet and other symbols . | https://tinyurl.com/c2ph4xk  | National Cued Speech Association defines cued speech as &quot;a <span class="searchmatch">visual <span> mode of communication . Cued speech is used to convey spoken language in a visual format .                                                                 | https://tinyurl.com/yvo8ptok |
# | audio guide to Navajo alphabet                  | Hózhǫ́ Náhásdlį́į ́ – Language of the Holy People . Web site with flash and <span class="searchmatch">audio helps .                                                                                                                                                   | https://tinyurl.com/j5vymdg  | The International Phonetic system is an alphabetic system of phonetic notation . It is based on the phonetic system of the alphabet . Other symbols are used instead of phonetics symbols . The IAPA system is based primarily on the alphabet and other symbols . | https://tinyurl.com/c2ph4xk  |
# | roadmap of Navajo alphabet                      | Handbook of Language and Literacy Development – A <span class="searchmatch">Roadmap from 0 to 60 months – Reading – Parent/Careeriver&quot;. Reading Aloud, Reading Rockets. 19 June 2016 .                                                                        | https://tinyurl.com/yxf5qqk5 |                                                                                                                                                                                                                                                                    |                              |
# | summary of Navajo alphabet                      | The International Phonetic <span class="searchmatch">Alphabet</span> (IPA) is an alphabetic system . The IPA system is based on phonetic symbols . Boxes or other symbols are used instead of symbols .                                                            | https://tinyurl.com/c2ph4xk  | The tail originated in Spain as the bottom half <span class="searchmatch">of a miniature cursive cursive . Romanian and Latvian is misnamed &quot;cedilla in the Unicode standard .                                                                                | https://tinyurl.com/lq4qwwl  |
# | meaning and significance of Navajo alphabet     | The phonology of the language is intimately connected to its morphology . The entire range <span class="searchmatch">of contrastive consonants is used in the sound system .                                                                                       | https://tinyurl.com/22g59alb | Phonetic <span class="searchmatch">Alphabet</span> (IPA) For the distinction between [ ], / / and . ⟨ ⟩, see IPA § Bracket .                                                                                                                                       | https://tinyurl.com/y5p8xbym |
